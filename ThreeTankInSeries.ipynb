# %% [markdown]
# <a href="https://colab.research.google.com/github/chetools/CHE4071_Fall2025/blob/main/ThreeTankInSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from plotly.subplots import make_subplots
from scipy.integrate import solve_ivp

# %%
A = 1.2 #m2
Aout = 0.2 #m2
g=9.81 #m/s2
qin_ss = 0.5

h_ss = ((qin_ss/Aout)**2)/(2*g)

h3sp = 1.1*h_ss  #setpoint for liquid level of 3rd tank

Kc=5.  #Controller gain

def rhs(t, v):
    h1, h2, h3 = v
    qin0 = qin_ss + Kc * (h3sp - h3)  #Proportional only controller P-controller
    q1, q2, q3 = Aout*np.sqrt(2*g*h1), Aout*np.sqrt(2*g*h2), Aout*np.sqrt(2*g*h3)
    return np.array([(qin0 - q1)/A, (q1-q2)/A, (q2-q3)/A])

# %%
tend= 100.
res=solve_ivp(rhs, (0, tend), [h_ss]*3, dense_output=True, method='Radau')
res
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  8.036e-02 ...  9.750e+01  1.000e+02]
#         y: [[ 3.186e-01  3.289e-01 ...  3.446e-01  3.476e-01]
#             [ 3.186e-01  3.188e-01 ...  3.455e-01  3.464e-01]
#             [ 3.186e-01  3.186e-01 ...  3.463e-01  3.459e-01]]
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x7a928ea0b8f0>
#  t_events: None
#  y_events: None
#      nfev: 480
#      njev: 2
#       nlu: 22

# %%
tplot = np.linspace(0, tend, 1000)
h1, h2, h3 =res.sol(tplot)
fig=make_subplots()
fig.add_scatter(x=tplot, y=h1, mode='lines', name='h1')
fig.add_scatter(x=tplot, y=h2, mode='lines', name='h2')
fig.add_scatter(x=tplot, y=h3, mode='lines', name='h3')
fig.update_layout(width=600, height=400, template='plotly_dark')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
h3sp
# Out:
# 0.350407747196738
