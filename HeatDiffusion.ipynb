# %% [markdown]
# <a href="https://colab.research.google.com/github/chetools/CHE4071_Fall2025/blob/main/HeatDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default = "plotly_dark"

import jax
import jax.numpy as jnp
jax.config.update("jax_enable_x64", True)

# %%
alpha = 1.  #m2/s
dx = 0.25
dt = 0.01

r = dt*alpha/(dx**2)
N=100

# %%
r=0.4999999

# %%
T=np.full(N,20.)
T[0]=50.
T[-1]=100
Tprofiles = [T.copy()]

# %%
for i in range(20000):
    T[1:-1] = T[1:-1] + r*(T[:-2] -2*T[1:-1] + T[2:] )
    Tprofiles.append(T.copy())

# %%
fig = make_subplots()
for i,Tprofile in enumerate(Tprofiles[::1000]):
    fig.add_scatter(x=np.arange(N), y=Tprofile, name = f'{i*1000*dt:4.1f}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Crank-Nicolson

# %%
T=np.full(N,20)

# %%
T.dtype
# Out:
# dtype('int64')

# %%
T[1:-1]*=0.7
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# /tmp/ipython-input-1486889700.py in <cell line: 0>()
# ----> 1 T[1:-1]*=0.7
#
# UFuncTypeError: Cannot cast ufunc 'multiply' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %%
r=2.
N=100
T=np.full(N,20.)
T[0]=50.
T[-1]=100.
ab=np.stack([np.full(N-2, -r), np.full(N-2, 1+2*r), np.full(N-2, -r)])
Tprofiles = [T.copy()]
for i in range(1000):
    b=r*T[:-2]+ (1-2*r)*T[1:-1] + r*T[2:]
    b[0]+=r*T[0]
    b[-1]+=r*T[-1]
    T[1:-1] = sp.linalg.solve_banded((1,1), ab, b )
    Tprofiles.append(T.copy())

# %%
fig = make_subplots()
for i,Tprofile in enumerate(Tprofiles[::50]):
    fig.add_scatter(x=np.arange(N), y=Tprofile, name = f'{i*50*dt:4.1f}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
